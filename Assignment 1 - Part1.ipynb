# %% [markdown]
# # !!!PRAVEEN----

# %% [markdown]
# # !!! EXECUTE FROM SECTION 2. ONLY EXECUTE LIBRARY LOADING IN SECTION 1. OTHERWISE THE FILES WILL GET CLEARED!!!

# %% [markdown]
# # 1. Pulling Tweets

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import re
import string
import datetime

import tweepy as tw
import nltk


ACCESS_TOKEN = '1571224944087912448-ukqDTMtQ5FY16uko7Rq5aewJyIh4aK'
ACCESS_TOKEN_SECRET = 'o4bUHYPx727KqpZ8OZqEttpOyDEaukUfTkv0rTi5OLNyM'

CONSUMER_API_KEY = 'Tpbpu8yQcurN8q3Jdqq9KqLHE'
CONSUMER_API_SECRET = 'Bafu0uAD6hxKEIVuD6EsvFcLIkSFlW3iI0XlQEncKKbKMPIfqR'

#Create an authentication object
my_auth_obj = tw.OAuthHandler(CONSUMER_API_KEY, CONSUMER_API_SECRET)

#Set access token to auth object
my_auth_obj.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

#Create an API Object to get tweets using authentication object
my_api = tw.API(my_auth_obj)
filetags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]

# %% [markdown]
# ## Creating the files - ONE TIME EXECUTION

# %%
#Creating files for all tags(ONE TIME EXECUTION)
for item in filetags:
    filepath = 'data/' + item + '.csv'
    df = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])
    df.to_csv(filepath, mode='a', index=False, header=True)

# %% [markdown]
# ## Defining functions for scrapping tweets and writing them to the file

# %%
#Function to scrap data
def scrap(date):
    query = "#Altcoin OR #Bitcoin OR #Coindesk OR #Cryptocurrency OR #Gold OR #APPL OR #GOOG OR #YHOO"
    tweets = tw.Cursor(my_api.search_tweets, q = query, until = date, tweet_mode = 'extended').items(2000)
    print(f"Scrapping completed Successfully for {date}!")
    return tweets

#Function for writing pulled data into dataframe and file
def write_to_df_and_file(word,tweetsdf):
    filepath = 'data/' + word + '.csv'
    
    #Getting length of the existing data
    df = pd.read_csv(filepath)
    l = df.index
    #Dropping all the rows in dataframe
    df.drop(l, inplace=True)
    
    hashw = '#'+word
    
    for i in range(len(tweetsdf)):
        if re.search(hashw.lower(),tweetsdf.loc[i, "Text"].lower()):
            df.loc[len(df.index)] = [tweetsdf.loc[i,"Tweet ID"], tweetsdf.loc[i,"Time of Tweet"], tweetsdf.loc[i,"User ID"], tweetsdf.loc[i,"Text"]]

    df.to_csv(filepath, mode='a', index=False, header=False)
    print(f"Tweet data about '{word}' is written into corresponding file.")

# %% [markdown]
# ## Pulling tweets date wise for all tags and saving them in file

# %%
#Pulling data before 2022-11-06 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-06'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-06!
# Data is written to the main dataframe of shape (2000, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-06!

# %%
#Pulling data before 2022-11-07 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-07'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-07!
# Data is written to the main dataframe of shape (2000, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-07!

# %%
#Pulling data before 2022-11-08 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-08'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-08!
# Data is written to the main dataframe of shape (1222, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-08!

# %%
#Pulling data before 2022-11-09 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-09'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-09!
# Data is written to the main dataframe of shape (1239, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-09!

# %%
#Pulling data before 2022-11-10 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-10'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-10!
# Data is written to the main dataframe of shape (2000, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-10!

# %%
#Pulling data before 2022-11-11 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-10'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-10!
# Data is written to the main dataframe of shape (2000, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-10!

# %%
#Pulling data before 2022-11-12 00:00:00
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
date = '2022-11-12'
tweets = scrap(date)

#Main dataframe for storing tweets
fdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text'])

for tweet in tweets:
    tweet_id = tweet.id
    time_of_tweet = tweet.created_at
    user_id = tweet.user.id
    text = tweet.full_text
    fdf.loc[len(fdf.index)] = [tweet_id, time_of_tweet, user_id, text]
    
print(f"Data is written to the main dataframe of shape {fdf.shape}.")

for tag in hashtags:
    write_to_df_and_file(tag,fdf)
    
#Dropping main dataframe
del fdf
print(f"Droped the main dataframe of date {date}!")
# Out:
# Scrapping completed Successfully for 2022-11-12!
# Data is written to the main dataframe of shape (2000, 4).
# Tweet data about 'Altcoin' is written into corresponding file.
# Tweet data about 'Bitcoin' is written into corresponding file.
# Tweet data about 'Coindesk' is written into corresponding file.
# Tweet data about 'Cryptocurrency' is written into corresponding file.
# Tweet data about 'Gold' is written into corresponding file.
# Tweet data about 'APPL' is written into corresponding file.
# Tweet data about 'GOOG' is written into corresponding file.
# Tweet data about 'YHOO' is written into corresponding file.
# Droped the main dataframe of date 2022-11-12!

# %% [markdown]
# # 2. Cleaning the dataset

# %%
#Initialising combined data frame
hashtags = ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]
cdf = pd.DataFrame(columns=['Tweet ID', 'Time of Tweet', 'User ID','Text','Tag'])

#Taking data from each file and appending to the maindataframe, and its type
for tag in hashtags:
    df = pd.read_csv('data/'+tag+'.csv')
    df["Tag"] = [tag] * df.shape[0]
    cdf = pd.concat([cdf,df])

# %% [markdown]
# ## Dropping duplicates

# %%
#Size before dropping duplicates
print(cdf.shape)

#dropping duplicates from combined dataframe
cdf.drop_duplicates()

#Size after dropping duplicates
print(cdf.shape)
# Out:
# (10951, 5)
# (10951, 5)

# %% [markdown]
# ## Remove Punctuations

# %%
#Remove Punctuations
cdf["Text"] = cdf["Text"].map(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
cdf.head()
# Out:
#               Tweet ID              Time of Tweet              User ID  \
# 0  1589044882676813824  2022-11-05 23:59:57+00:00            911069258
# 1  1589044550886379520  2022-11-05 23:58:38+00:00  1551067188882116608
# 2  1589044536378298371  2022-11-05 23:58:35+00:00  1585083640114970624
# 3  1589044431520673793  2022-11-05 23:58:10+00:00  1546364668503298048
# 4  1589044402164416512  2022-11-05 23:58:03+00:00  1568222677860597760
#
#                                                 Text      Tag
# 0  ElonGoatToken VoltInuOfficial VOLTINU CRYPTO D...  Altcoin
# 1  Ethereum price update \n\nETH 162841 USD\nBitc...  Altcoin
# 2  With Gonfty project you have chance to be earl...  Altcoin
# 3  BinanceCoin price update BNB\n\nBNB 34956 USD\...  Altcoin
# 4  101whaale AltGemsAlert Can you give me a gem t...  Altcoin

# %% [markdown]
# ## Removing Emojis

# %%
#Removing Emojis
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)


cdf["Text"] = cdf["Text"].map(lambda x: remove_emoji(x))
cdf.head()
# Out:
#               Tweet ID              Time of Tweet              User ID  \
# 0  1589044882676813824  2022-11-05 23:59:57+00:00            911069258
# 1  1589044550886379520  2022-11-05 23:58:38+00:00  1551067188882116608
# 2  1589044536378298371  2022-11-05 23:58:35+00:00  1585083640114970624
# 3  1589044431520673793  2022-11-05 23:58:10+00:00  1546364668503298048
# 4  1589044402164416512  2022-11-05 23:58:03+00:00  1568222677860597760
#
#                                                 Text      Tag
# 0  ElonGoatToken VoltInuOfficial VOLTINU CRYPTO D...  Altcoin
# 1  Ethereum price update \n\nETH 162841 USD\nBitc...  Altcoin
# 2  With Gonfty project you have chance to be earl...  Altcoin
# 3  BinanceCoin price update BNB\n\nBNB 34956 USD\...  Altcoin
# 4  101whaale AltGemsAlert Can you give me a gem t...  Altcoin

# %% [markdown]
# ## Removing Numbers

# %%
#Removing numbers in Tweet
def remove_numbers(string):
    pattern = re.compile("[0-9]+")
    return pattern.sub(r'', string)

cdf["Text"] = cdf["Text"].map(lambda x: remove_numbers(x))
cdf.head()
# Out:
#               Tweet ID              Time of Tweet              User ID  \
# 0  1589044882676813824  2022-11-05 23:59:57+00:00            911069258
# 1  1589044550886379520  2022-11-05 23:58:38+00:00  1551067188882116608
# 2  1589044536378298371  2022-11-05 23:58:35+00:00  1585083640114970624
# 3  1589044431520673793  2022-11-05 23:58:10+00:00  1546364668503298048
# 4  1589044402164416512  2022-11-05 23:58:03+00:00  1568222677860597760
#
#                                                 Text      Tag
# 0  ElonGoatToken VoltInuOfficial VOLTINU CRYPTO D...  Altcoin
# 1  Ethereum price update \n\nETH  USD\nBitcoin  B...  Altcoin
# 2  With Gonfty project you have chance to be earl...  Altcoin
# 3  BinanceCoin price update BNB\n\nBNB  USD\n\nBi...  Altcoin
# 4  whaale AltGemsAlert Can you give me a gem to b...  Altcoin

# %% [markdown]
# ## Removing words having length less than 2

# %%
#Remove words with length less than 2
def remove_words_lessthan_two(string):
    pattern = re.compile(r'\b\w{1}\b')
    return pattern.sub(r'',string)

cdf["Text"] = cdf["Text"].map(lambda x: remove_words_lessthan_two(x))
cdf.head()
# Out:
#               Tweet ID Time of Tweet              User ID  \
# 0  1589044882676813824    2022-11-05            911069258
# 1  1589044550886379520    2022-11-05  1551067188882116608
# 2  1589044536378298371    2022-11-05  1585083640114970624
# 3  1589044431520673793    2022-11-05  1546364668503298048
# 4  1589044402164416512    2022-11-05  1568222677860597760
#
#                                                 Text      Tag
# 0  ElonGoatToken VoltInuOfficial VOLTINU CRYPTO D...  Altcoin
# 1  Ethereum price update \n\nETH  USD\nBitcoin  B...  Altcoin
# 2  With Gonfty project you have chance to be earl...  Altcoin
# 3  BinanceCoin price update BNB\n\nBNB  USD\n\nBi...  Altcoin
# 4  whaale AltGemsAlert Can you give me  gem to bu...  Altcoin

# %% [markdown]
# ## Converting Date Format

# %%
cdf['Time of Tweet'] = cdf['Time of Tweet'].map(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S+00:00").date())

# %% [markdown]
# # 3. Visualization

# %% [markdown]
# ### 3.1 Daily Tweet Counts

# %%
df = cdf.groupby(['Time of Tweet', 'Tag']).agg({'Text': ['count']}).unstack(fill_value=0).stack()
df.columns = ['Tweet Count']
df = df.reset_index()
df
# Out:
#    Time of Tweet             Tag  Tweet Count
# 0     2022-11-05            APPL            1
# 1     2022-11-05         Altcoin           79
# 2     2022-11-05         Bitcoin         1126
# 3     2022-11-05        Coindesk            0
# 4     2022-11-05  Cryptocurrency          401
# 5     2022-11-05            GOOG            1
# 6     2022-11-05            Gold           50
# 7     2022-11-06            APPL            2
# 8     2022-11-06         Altcoin          117
# 9     2022-11-06         Bitcoin         1322
# 10    2022-11-06        Coindesk            0
# 11    2022-11-06  Cryptocurrency          338
# 12    2022-11-06            GOOG            2
# 13    2022-11-06            Gold           76
# 14    2022-11-07            APPL            0
# 15    2022-11-07         Altcoin           68
# 16    2022-11-07         Bitcoin          677
# 17    2022-11-07        Coindesk            0
# 18    2022-11-07  Cryptocurrency          183
# ...

# %%
sns.set_context('talk')
sns.set_style('darkgrid')
fig, ax = plt.subplots(figsize=(15, 8))
x = np.arange(len(df['Time of Tweet'].unique()))
bar_width = 0.2

# ["Altcoin", "Bitcoin", "Coindesk", "Cryptocurrency", "Gold", "APPL", "GOOG", "YHOO"]

b1 = ax.bar(x, df.loc[df['Tag'] == 'Altcoin', 'Tweet Count'],
            width=bar_width,label='Altcoin')
b2 = ax.bar(x + bar_width, df.loc[df['Tag'] == 'Bitcoin', 'Tweet Count'],
            width=bar_width,label='Bitcoin')
b3 = ax.bar(x + (2*bar_width), df.loc[df['Tag'] == 'Cryptocurrency', 'Tweet Count'],
            width=bar_width,label='Cryptocurrency')
b4 = ax.bar(x + 3*bar_width, df.loc[df['Tag'] == 'Coindesk', 'Tweet Count'],
            width=bar_width,label='Coindesk')
b5 = ax.bar(x + 4*bar_width, df.loc[df['Tag'] == 'Gold', 'Tweet Count'],
            width=bar_width,label='Gold')
b6 = ax.bar(x + 5*bar_width, df.loc[df['Tag'] == 'APPL', 'Tweet Count'],
            width=bar_width,label='APPL')
b7 = ax.bar(x + 5*bar_width, df.loc[df['Tag'] == 'GOOG', 'Tweet Count'],
            width=bar_width,label='GOOG')

# Fix the x-axes.
ax.set_xticks(x + bar_width)
ax.set_xticklabels(df['Time of Tweet'].unique())
ax.legend()

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels.
ax.set_xlabel('Date', labelpad=15)
ax.set_ylabel('# Tweets', labelpad=15)
ax.set_title('Tweet Count by Keywords for Select Dates', pad=15)

fig.tight_layout()

# %% [markdown]
# ### 3.2 Daily Number of Users

# %%
df2 = cdf.groupby('Time of Tweet')['User ID'].nunique()
df2 = df2.reset_index()
df2.columns = ['Time of Tweet','UserID Count']
df2
# Out:
#   Time of Tweet  UserID Count
# 0    2022-11-05           923
# 1    2022-11-06          1235
# 2    2022-11-07           573
# 3    2022-11-08           750
# 4    2022-11-09          1253
# 5    2022-11-11          1081

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x=df2['Time of Tweet'],y=df2['UserID Count'])
# Out:
# <AxesSubplot:xlabel='Time of Tweet', ylabel='UserID Count'>
